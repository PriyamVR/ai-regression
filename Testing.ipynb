# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from joblib import dump, load

# Load the model
loaded_model = load("/content/drive/MyDrive/ML/ML/Compressive strength/xgboost_model.joblib")
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
import pandas as pd

# Read new Excel data
new_data = pd.read_excel("/content/drive/MyDrive/ML/ML/Compressive strength/Test_additional.xlsx")

# %%
# Ensure feature names align with training data
predictions = loaded_model.predict(new_data)

# Save predictions to a new Excel file
output = pd.DataFrame(predictions, columns=["Predicted Values"])

# %%
output
# Out:
#     Predicted Values
# 0          50.243355
# 1          47.172005
# 2          50.243355
# 3          47.172005
# 4          50.243355
# 5          60.581055
# 6          60.581055
# 7          60.581055
# 8          60.581055
# 9          60.581055
# 10         60.581055
# 11         60.581055
# 12         60.581055
# 13         60.581055
# 14         60.581055
# 15         60.581055
# 16         60.581055

# %%
output = pd.DataFrame(new_data)
output["Predicted Values"] = predictions


output
# Out:
#     Cement  Lime  Flyash  GGBS  Silica  RHA  coarse  Fineagg  Water    SP  \
# 0    220.0     0   330.0     0     0.0    0   937.0    796.0  172.0  2.64
# 1    552.0     0     0.0     0     0.0    0  1486.0    342.0  160.0  5.52
# 2    330.0     0   220.0     0     0.0    0   981.0    835.0  144.0  4.95
# 3    600.0     0     0.0     0     0.0    0  1462.0    336.0  155.0  7.20
# 4    440.0     0   110.0     0     0.0    0   989.0    841.0  142.0  6.60
# 5    412.5     0   137.5     0     0.0    0   520.1    612.7  203.5  0.00
# 6    401.5     0   137.5     0    11.0    0   518.6    610.9  203.5  0.00
# 7    385.0     0   137.5     0    27.5    0   516.8    608.8  203.5  0.00
# 8    412.5     0   137.5     0     0.0    0   523.1    612.7  203.5  0.00
# 9    401.5     0   137.5     0    11.0    0   521.6    610.9  203.5  0.00
# 10   385.0     0   137.5     0    27.5    0   519.8    608.8  203.5  0.00
# 11   337.5     0   112.5     0     0.0    0   531.9    626.5  225.0  0.00
# ...
